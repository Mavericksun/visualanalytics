# %%
from UTCDAL.Utilities.Visualization.i_plot import i_bar, i_line,i_scatter, i_heatmap, i_carpetplot, i_line_marks
import pandas as pd
pd.set_option('max_rows', 200)
pd.set_option('max_columns', 200)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pymysql
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Load function package

# %%
df = pd.read_csv('Iris-data.csv')
df.head()
# Out:
#     a1   a2   a3   a4    id        label
# 0  5.1  3.5  1.4  0.2  id_1  Iris-setosa
# 1  4.9  3.0  1.4  0.2  id_2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  id_3  Iris-setosa
# 3  4.6  3.1  1.5  0.2  id_4  Iris-setosa
# 4  5.0  3.6  1.4  0.2  id_5  Iris-setosa

# %%
df.describe() ##Have an overview of dataset discription and know centralization and distribution
# Out:
#                a1          a2          a3          a4
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.label.value_counts() ##know how many types of categorical parameter
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: label, dtype: int64

# %%
i_bar(df, 'id',
      ['a1', 'a2', 'a3', 'a4'],
      xaxis_interval=0, xaxis_rotate=60)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="16b8d7e8d88f4001b282cadafa1e7cc3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_16b8d7e8d88f4001b282cadafa1e7cc3 = echarts.init(document.getElementById('16b8d7e8d88f4001b282cadafa1e7cc3'), 'light', {renderer: 'canvas'});
#
# var option_16b8d7e8d88f4001b282cadafa1e7cc3 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
# ...

# %%
i_bar(df, 'id',
      ['a1', 'a2'],
      ['a3', 'a4'],
      xaxis_interval=0, xaxis_rotate=60, datazoom_type='both')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4f6cc8f32cee4f87945f31205bce47a0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4f6cc8f32cee4f87945f31205bce47a0 = echarts.init(document.getElementById('4f6cc8f32cee4f87945f31205bce47a0'), 'light', {renderer: 'canvas'});
#
# var option_4f6cc8f32cee4f87945f31205bce47a0 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
# ...

# %% [markdown]
# Bar plot can be adjusted according to the column number of dataset.

# %%
i_line(df, 'id',
      ['a1', 'a2'],
      ['a3', 'a4'],
      xaxis_interval=0, xaxis_rotate=60, datazoom_type='both')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2abde0e8ff13472bb68ba53ba3f1f8ab" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2abde0e8ff13472bb68ba53ba3f1f8ab = echarts.init(document.getElementById('2abde0e8ff13472bb68ba53ba3f1f8ab'), 'light', {renderer: 'canvas'});
#
# var option_2abde0e8ff13472bb68ba53ba3f1f8ab = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         },
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
# ...

# %% [markdown]
# #### 4. 3dplot
# ![3dplot]({filename}/static/3dplot.gif)
#
# #### 5. Scroll to zoom in line chart
#
# ![normalize line]({filename}/static/normalize-line.gif)
#
# #### 6.scroll to zoom in dot
#
# ![scroll to zoom]({filename}/static/scroll-to-zoom.gif)
#
# #### 7.carpet plot
# ![Carpet plot]({filename}/static/carpetplot.gif)

# %%
# Out:
#                        values
# 2016-05-01 00:00:00  0.000375
# 2016-05-01 00:01:00  0.000369
# 2016-05-01 00:02:00  0.000655
# 2016-05-01 00:03:00  0.001391
# 2016-05-01 00:04:00  0.001001

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ddd32fe3075c> in <module>()
# ----> 1 i_carpetplot(df1)
#
# d:\analytics_utc_library\utcdal\utcdal\UTCDAL\Utilities\Visualization\i_plot.py in i_carpetplot(df, column, title, vmin, vmax)
#     233         else:
#     234             raise ValueError('A column name must be specified.')
# --> 235     df['date'] = [d.strftime('%Y-%m-%d') for d in df.index]
#     236     df['time'] = [d.strftime('%H:%M:%S') for d in df.index]
#     237     df1 = df.pivot_table(column, index='time', columns='date')
#
# d:\analytics_utc_library\utcdal\utcdal\UTCDAL\Utilities\Visualization\i_plot.py in <listcomp>(.0)
#     233         else:
#     234             raise ValueError('A column name must be specified.')
# --> 235     df['date'] = [d.strftime('%Y-%m-%d') for d in df.index]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9f1655132055> in <module>()
#       4 data=[trace]
#       5 data
# ----> 6 i_carpetplot(data)
#
# d:\analytics_utc_library\utcdal\utcdal\UTCDAL\Utilities\Visualization\i_plot.py in i_carpetplot(df, column, title, vmin, vmax)
#     229         df = pd.DataFrame(tseries)
#     230     if column is None:
# --> 231         if df.shape[1] == 1:
#     232             column = df.columns[0]
#     233         else:
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-604bf95bf4bc> in <module>()
#       1 start, end = '2017-01', '2017-06'
# ----> 2 i_carpetplot(df1['oprating hour']()[start:end],'operating hour')
#
# TypeError: 'Series' object is not callable
